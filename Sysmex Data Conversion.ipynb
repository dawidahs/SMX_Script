# %% [markdown]
# Import pandas and read the csv file

# %%
import pandas as pd

df = pd.read_csv('Absence_Request.csv')

# %% [markdown]
# Define the mapping

# %%
work_type = {
    "DEU":"DE_001",
    "ESP":"ES_001",
    "CHE":"CH_001",
    "SWE":"SE_001"
    }

sick_type = {
    "DEU":"DE_002",
    "ESP":"ES_003",
    "CHE":"CH_002",
    "SWE":"SE_002"
}

# %% [markdown]
# Replace the values in the time type column for the mapped values based on the country

# %%
df.loc[df['timeType.externalCode'] == "WORK", 'timeType.externalCode'] = df['Country'].map(work_type)
df.loc[df['timeType.externalCode'] == "SICK", 'timeType.externalCode'] = df['Country'].map(sick_type)

print(df['timeType.externalCode'])
# Out:
# 0    Time Type.External Code
# 1                     DE_001
# 2                     ES_001
# 3                     DE_002
# 4                     CH_001
# 5                     SE_001
# 6                     CH_001
# Name: timeType.externalCode, dtype: object

# %% [markdown]
# Remove the Country column

# %%
df = df.drop(columns = ['Country'])

# %% [markdown]
# Write a new CSV file

# %%
df.to_csv('Absence_Rquest_updated.csv', index=False)
